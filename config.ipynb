# %%
"""
Configuration settings for coagulation analysis
"""

# Data paths
DATA_PATH = "dir/data.xlsx"

# Column definitions
ID_COLS = ['ID']
TIME_COL = 'Time'

FEATURE_COLS = [
    'TAT', 'PIC', 'PAIC', 'TM', 'PT', 'APTT', 'TT', 'Fib', 'DD', 
    'PLT', 'Hb', 'HCT', 'CRP', 'LDH', 'GOT_AST', 'GPT_ALT', 'Ca'
]

KEY_COLS = [
    'TAT', 'PIC', 'PAIC', 'TM', 'PT', 'APTT', 'TT', 'Fib', 'DD', 
    'PLT', 'Hb', 'HCT'
]

LAB_TESTS = [
    'TAT', 'PIC', 'PAIC', 'TM', 'PT', 'APTT', 'TT', 'Fib', 'DD', 
    'PLT', 'Hb', 'HCT', 'CRP'
]

# Treatment categories
ANTICOAGULANTS = [
    'Heparin Sodium', 'Low Molecular Weight Heparin', 'Enoxaparin Sodium', 
    'Nadroparin Calcium', 'Dalteparin Sodium'
]

ANTIPLATELETS = [
    'Aspirin Enteric-coated Tablets', 'Clopidogrel Tablets', 
    'Clopidogrel Hydrogen Sulfate Tablets', 'Argatroban Injection',
    'Rivaroxaban Tablets', 'Apixaban Tablets', 'Ticagrelor Tablets',
    'Tirofiban Injection', 'Tirofiban Hydrochloride Sodium Chloride Injection'
]

HEMOSTATICS = [
    'Tranexamic Acid', 'Vitamin K1 Injection', 'Batroxobin',
    'Snake Venom Hemocoagulase Injection', 'Etamsylate Injection',
    'Acutobin', 'Human Prothrombin Complex Concentrate'
]

BLOOD_PRODUCTS = [
    'Red Blood Cells', 'Frozen Plasma', 'Cryoprecipitate', 
    'Plasma', 'Leukocyte-depleted Platelet Apheresis'
]

# RL parameters
TARGET_STATE = np.array([0, 0])
ALPHA = 0.1
GAMMA = 0.99
EPS = 1e-8

# Model parameters
HIDDEN_DIM = 64
NUM_LAYERS = 2
DROPOUT = 0.3
LEARNING_RATE = 1e-4
EPOCHS = 50
BATCH_SIZE = 32
MAX_STEPS = 8
